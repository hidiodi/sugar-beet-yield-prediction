# %% [markdown]
# # Complete Sugar Beet Yield Prediction Pipeline Orchestrator

# %% [markdown]
# ## Introduction
# This notebook orchestrates the entire, end-to-end pipeline for predicting sugar beet yield in Germany. It calls all necessary Python scripts in the correct sequence to perform data downloading, processing, feature engineering, model training, and analysis. This notebook serves as the master controller for the whole project.

# %% [markdown]
# ## Part 1: Initial Data Downloading and Processing
# This section covers the download and initial processing of all raw data sources, including agronomic data, static geographic features, and weather data from AGERA5 and SEAS5.

# %% [markdown]
# ### Step 1.1: Build Static Features
# This script uses Google Earth Engine to calculate static features like elevation and Plant Available Water Capacity (PAWC) for each district. This is typically a one-time setup step.

# %%
# %run src/01_data/Staticland_data/build_static_features.py

# %% [markdown]
# ### Step 1.2: Download Agronomic Data
# Downloads the primary crop yield data.

# %%
# %run src/01_data/Weather_Data/AGERA_Weatherdata/01_download_agronomic_data.py

# %% [markdown]
# ### Step 1.3: Download AGERA5 Weather Data
# Downloads the historical weather data from the AGERA5 dataset.

# %%
# %run src/01_data/Weather_Data/AGERA_Weatherdata/02_download_agera5_data.py

# %% [markdown]
# ### Step 1.4: Process AGERA5 Weather Data
# Processes the downloaded raw AGERA5 data into a usable format.

# %%
# %run src/01_data/Weather_Data/AGERA_Weatherdata/03_process_agera5_data.py

# %% [markdown]
# ### Step 1.5: Download SEAS5 Seasonal Forecast Data
# Downloads the seasonal forecast data from the SEAS5 dataset.

# %%
# %run src/01_data/Weather_Data/SEASForecastData/SEAS5/02_Download_seasonal_forecasts.py

# %% [markdown]
# ### Step 1.6: Process SEAS5 Seasonal Forecast Data
# Processes the raw SEAS5 data.

# %%
# %run src/01_data/Weather_Data/SEASForecastData/SEAS5/03_process_seas5_data.py

# %% [markdown]
# ### Step 1.7: Create AGERA5 Ground Truth
# Creates a 'ground truth' dataset from the AGERA5 data for forecast evaluation.

# %%
# %run src/01_data/Weather_Data/SEASForecastData/04b_create_agera5_ground_truth.py

# %% [markdown]
# ## Part 2: Data Integration and Feature Engineering
# This section integrates the various processed datasets into master tables.

# %% [markdown]
# ### Step 2.1: Create Crop Dataset with Weather
# Merges the crop yield data with the processed AGERA5 and SEAS5 weather features.

# %%
# %run src/01_data/Weather_Data/04_create_crop_dataset_with_weather.py

# %% [markdown]
# ### Step 2.2: Create Master Dataset
# Combines the weather-crop data with static features and economic data to create the final master dataset used for modeling.

# %%
# %run src/01_data/Master_Orchestrator/create_master_dataset.py

# %% [markdown]
# ### Step 2.3: Build Stage 1 Features
# Performs the final feature engineering steps required for the pre-season forecast model.

# %%
# %run src/01_data/build_stage1_features.py

# %% [markdown]
# ## Part 3: Modeling and Analysis
# This final section runs the model training and explanation scripts.

# %% [markdown]
# ### Step 3.1: Train and Evaluate Base Model
# Trains the final XGBoost regression model, evaluates its performance, and saves the model artifact.

# %%
# %run src/02_models/XGBoost/regression_model/ModelScripts/base_model.py

# %run src/02_models/XGBoost/regression_model/Testing/backtesting.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\PycharmProjects\sugar-beet-yield-prediction\.venv\Lib\site-packages\IPython\core\magics\execution.py:728, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     727     fpath = arg_lst[0]
# --> 728     filename = file_finder(fpath)
#     729 except IndexError as e:
#
# File ~\PycharmProjects\sugar-beet-yield-prediction\.venv\Lib\site-packages\IPython\utils\path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'src/02_models/XGBoost/regression_model/ModelScripts/base_model.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 1
# ...

# %% [markdown]
# ### Step 3.2: Explain Model Predictions
# Loads the trained model and uses SHAP to generate and save explanations and analysis plots.

# %%
# %run src/03_analysis/explain_stage1_model.py
